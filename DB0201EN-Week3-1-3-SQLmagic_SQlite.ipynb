# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# # Accessing Databases with SQL Magic
#
# Estimated time needed: **15** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Perform simplified database access using SQL "magic"

# %% [markdown]
# ##### To communicate with SQL Databases from within a JupyterLab notebook, we can use the SQL "magic" provided by the [ipython-sql](https://github.com/catherinedevlin/ipython-sql) extension. "Magic" is JupyterLab's term for special commands that start with "%". Below, we'll use the *load*\_*ext* magic to load the ipython-sql extension. In the lab environemnt provided in the course the ipython-sql extension is already installed and so is the ibm_db_sa driver.

# %%
# %load_ext sql

# %% [markdown]
# ##### Here  you will  be creating and connecting to a new SQlite database SQLiteMagic.
#
# ##### The syntax for connecting to magic sql using sqllite is
#
#   **%sql sqlite://DatabaseName**
#
# where DatabaseName will be your **.db** file

# %%
import csv, sqlite3

con = sqlite3.connect("SQLiteMagic.db")
cur = con.cursor()

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///SQLiteMagic.db
# Out:
# 'Connected: @SQLiteMagic.db'

# %% [markdown]
# ##### For convenience, we can use %%sql (two %'s instead of one) at the top of a cell to indicate we want the entire cell to be treated as SQL. Let's use this to create a table and fill it with some test data for experimenting.

# %%
# %%sql
#
# CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );
# INSERT INTO INTERNATIONAL_STUDENT_TEST_SCORES (country, first_name, last_name, test_score)
# VALUES
# ('United States', 'Marshall', 'Bernadot', 54),
# ('Ghana', 'Celinda', 'Malkin', 51),
# ('Ukraine', 'Guillermo', 'Furze', 53),
# ('Greece', 'Aharon', 'Tunnow', 48),
# ('Russia', 'Bail', 'Goodwin', 46),
# ('Poland', 'Cole', 'Winteringham', 49),
# ('Sweden', 'Emlyn', 'Erricker', 55),
# ('Russia', 'Cathee', 'Sivewright', 49),
# ('China', 'Barny', 'Ingerson', 57),
# ('Uganda', 'Sharla', 'Papaccio', 55),
# ('China', 'Stella', 'Youens', 51),
# ('Poland', 'Julio', 'Buesden', 48),
# ('United States', 'Tiffie', 'Cosely', 58),
# ('Poland', 'Auroora', 'Stiffell', 45),
# ('China', 'Clarita', 'Huet', 52),
# ('Poland', 'Shannon', 'Goulden', 45),
# ('Philippines', 'Emylee', 'Privost', 50),
# ('France', 'Madelina', 'Burk', 49),
# ('China', 'Saunderson', 'Root', 58),
# ('Indonesia', 'Bo', 'Waring', 55),
# ('China', 'Hollis', 'Domotor', 45),
# ('Russia', 'Robbie', 'Collip', 46),
# ('Philippines', 'Davon', 'Donisi', 46),
# ('China', 'Cristabel', 'Radeliffe', 48),
# ('China', 'Wallis', 'Bartleet', 58),
# ('Moldova', 'Arleen', 'Stailey', 38),
# ('Ireland', 'Mendel', 'Grumble', 58),
# ('China', 'Sallyann', 'Exley', 51),
# ('Mexico', 'Kain', 'Swaite', 46),
# ('Indonesia', 'Alonso', 'Bulteel', 45),
# ('Armenia', 'Anatol', 'Tankus', 51),
# ('Indonesia', 'Coralyn', 'Dawkins', 48),
# ('China', 'Deanne', 'Edwinson', 45),
# ('China', 'Georgiana', 'Epple', 51),
# ('Portugal', 'Bartlet', 'Breese', 56),
# ('Azerbaijan', 'Idalina', 'Lukash', 50),
# ('France', 'Livvie', 'Flory', 54),
# ('Malaysia', 'Nonie', 'Borit', 48),
# ('Indonesia', 'Clio', 'Mugg', 47),
# ('Brazil', 'Westley', 'Measor', 48),
# ('Philippines', 'Katrinka', 'Sibbert', 51),
# ('Poland', 'Valentia', 'Mounch', 50),
# ('Norway', 'Sheilah', 'Hedditch', 53),
# ('Papua New Guinea', 'Itch', 'Jubb', 50),
# ('Latvia', 'Stesha', 'Garnson', 53),
# ('Canada', 'Cristionna', 'Wadmore', 46),
# ('China', 'Lianna', 'Gatward', 43),
# ('Guatemala', 'Tanney', 'Vials', 48),
# ('France', 'Alma', 'Zavittieri', 44),
# ('China', 'Alvira', 'Tamas', 50),
# ('United States', 'Shanon', 'Peres', 45),
# ('Sweden', 'Maisey', 'Lynas', 53),
# ('Indonesia', 'Kip', 'Hothersall', 46),
# ('China', 'Cash', 'Landis', 48),
# ('Panama', 'Kennith', 'Digance', 45),
# ('China', 'Ulberto', 'Riggeard', 48),
# ('Switzerland', 'Judy', 'Gilligan', 49),
# ('Philippines', 'Tod', 'Trevaskus', 52),
# ('Brazil', 'Herold', 'Heggs', 44),
# ('Latvia', 'Verney', 'Note', 50),
# ('Poland', 'Temp', 'Ribey', 50),
# ('China', 'Conroy', 'Egdal', 48),
# ('Japan', 'Gabie', 'Alessandone', 47),
# ('Ukraine', 'Devlen', 'Chaperlin', 54),
# ('France', 'Babbette', 'Turner', 51),
# ('Czech Republic', 'Virgil', 'Scotney', 52),
# ('Tajikistan', 'Zorina', 'Bedow', 49),
# ('China', 'Aidan', 'Rudeyeard', 50),
# ('Ireland', 'Saunder', 'MacLice', 48),
# ('France', 'Waly', 'Brunstan', 53),
# ('China', 'Gisele', 'Enns', 52),
# ('Peru', 'Mina', 'Winchester', 48),
# ('Japan', 'Torie', 'MacShirrie', 50),
# ('Russia', 'Benjamen', 'Kenford', 51),
# ('China', 'Etan', 'Burn', 53),
# ('Russia', 'Merralee', 'Chaperlin', 38),
# ('Indonesia', 'Lanny', 'Malam', 49),
# ('Canada', 'Wilhelm', 'Deeprose', 54),
# ('Czech Republic', 'Lari', 'Hillhouse', 48),
# ('China', 'Ossie', 'Woodley', 52),
# ('Macedonia', 'April', 'Tyer', 50),
# ('Vietnam', 'Madelon', 'Dansey', 53),
# ('Ukraine', 'Korella', 'McNamee', 52),
# ('Jamaica', 'Linnea', 'Cannam', 43),
# ('China', 'Mart', 'Coling', 52),
# ('Indonesia', 'Marna', 'Causbey', 47),
# ('China', 'Berni', 'Daintier', 55),
# ('Poland', 'Cynthia', 'Hassell', 49),
# ('Canada', 'Carma', 'Schule', 49),
# ('Indonesia', 'Malia', 'Blight', 48),
# ('China', 'Paulo', 'Seivertsen', 47),
# ('Niger', 'Kaylee', 'Hearley', 54),
# ('Japan', 'Maure', 'Jandak', 46),
# ('Argentina', 'Foss', 'Feavers', 45),
# ('Venezuela', 'Ron', 'Leggitt', 60),
# ('Russia', 'Flint', 'Gokes', 40),
# ('China', 'Linet', 'Conelly', 52),
# ('Philippines', 'Nikolas', 'Birtwell', 57),
# ('Australia', 'Eduard', 'Leipelt', 53)
# Out:
#  * sqlite:///SQLiteMagic.db
# (sqlite3.OperationalError) table INTERNATIONAL_STUDENT_TEST_SCORES already exists
# [SQL: CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# #### Using Python Variables in your SQL Statements
#
# ##### You can use python variables in your SQL statements by adding a ":" prefix to your python variable names.
#
# ##### For example, if I have a python variable `country` with a value of `"Canada"`, I can use this variable in a SQL query to find all the rows of students from Canada.

# %%
country = "Canada"
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES where country = :country
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# [('Canada', 'Cristionna', 'Wadmore', 46),
#  ('Canada', 'Wilhelm', 'Deeprose', 54),
#  ('Canada', 'Carma', 'Schule', 49)]

# %% [markdown]
# #### Assigning the Results of Queries to Python Variables

# %% [markdown]
# ##### You can use the normal python assignment syntax to assign the results of your queries to python variables.
#
# ##### For example, I have a SQL query to retrieve the distribution of test scores (i.e. how many students got each score). I can assign the result of this query to the variable `test_score_distribution` using the `=` operator.

# %%
test_score_distribution = %sql SELECT test_score as "Test_Score", count(*) as "Frequency" from INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score;
test_score_distribution
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# [(38, 2),
#  (40, 1),
#  (43, 2),
#  (44, 2),
#  (45, 8),
#  (46, 7),
#  (47, 4),
#  (48, 14),
#  (49, 8),
#  (50, 10),
#  (51, 8),
#  (52, 8),
#  (53, 8),
#  (54, 5),
#  (55, 4),
#  (56, 1),
#  (57, 2),
#  (58, 4),
#  (60, 1)]

# %% [markdown]
# #### Converting Query Results to DataFrames

# %% [markdown]
# ##### You can easily convert a SQL query result to a pandas dataframe using the `DataFrame()` method. Dataframe objects are much more versatile than SQL query result objects. For example, we can easily graph our test score distribution after converting to a dataframe.

# %%
dataframe = test_score_distribution.DataFrame()

# %matplotlib inline
# uncomment the following line if you get an module error saying seaborn not found
# !pip install seaborn==0.9.0
import seaborn

plot = seaborn.barplot(x='Test_Score',y='Frequency', data=dataframe)

# %% [markdown]
# Now you know how to work with Db2 from within JupyterLab notebooks using SQL "magic"!

# %%
# %%sql
#
# -- Feel free to experiment with the data set provided in this notebook for practice:
# SELECT country, first_name, last_name, test_score FROM INTERNATIONAL_STUDENT_TEST_SCORES;
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# [('United States', 'Marshall', 'Bernadot', 54),
#  ('Ghana', 'Celinda', 'Malkin', 51),
#  ('Ukraine', 'Guillermo', 'Furze', 53),
#  ('Greece', 'Aharon', 'Tunnow', 48),
#  ('Russia', 'Bail', 'Goodwin', 46),
#  ('Poland', 'Cole', 'Winteringham', 49),
#  ('Sweden', 'Emlyn', 'Erricker', 55),
#  ('Russia', 'Cathee', 'Sivewright', 49),
#  ('China', 'Barny', 'Ingerson', 57),
#  ('Uganda', 'Sharla', 'Papaccio', 55),
#  ('China', 'Stella', 'Youens', 51),
#  ('Poland', 'Julio', 'Buesden', 48),
#  ('United States', 'Tiffie', 'Cosely', 58),
#  ('Poland', 'Auroora', 'Stiffell', 45),
#  ('China', 'Clarita', 'Huet', 52),
#  ('Poland', 'Shannon', 'Goulden', 45),
#  ('Philippines', 'Emylee', 'Privost', 50),
#  ('France', 'Madelina', 'Burk', 49),
#  ('China', 'Saunderson', 'Root', 58),
#  ('Indonesia', 'Bo', 'Waring', 55),
#  ('China', 'Hollis', 'Domotor', 45),
#  ('Russia', 'Robbie', 'Collip', 46),
#  ('Philippines', 'Davon', 'Donisi', 46),
# ...

# %% [markdown]
# #### Basic Statistics:
#
# ###### What is the average test score of all international students?
# ###### What is the highest and lowest test score achieved?
# ###### What is the overall distribution of test scores?

# %%
# What is the average test score of all international students?

result = %sql SELECT AVG(test_score) AS Average_Test_Score FROM INTERNATIONAL_STUDENT_TEST_SCORES
print(result)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# +--------------------+
# | Average_Test_Score |
# +--------------------+
# | 49.73737373737374  |
# +--------------------+

# %%
# What is the highest test score achieved?

result1 = %sql select max(test_score) as Highest_Test_Score_Achieved, min(test_score) as Lowest_Test_Score_Achieved  from INTERNATIONAL_STUDENT_TEST_SCORES
print(result1)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# +-----------------------------+----------------------------+
# | Highest_Test_Score_Achieved | Lowest_Test_Score_Achieved |
# +-----------------------------+----------------------------+
# |              60             |             38             |
# +-----------------------------+----------------------------+

# %%
# What is the overall distribution of test scores?

result2 = %sql SELECT test_score, COUNT(*) AS Frequency FROM INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score ORDER BY test_score
print(result2)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# +------------+-----------+
# | test_score | Frequency |
# +------------+-----------+
# |     38     |     2     |
# |     40     |     1     |
# |     43     |     2     |
# |     44     |     2     |
# |     45     |     8     |
# |     46     |     7     |
# |     47     |     4     |
# |     48     |     14    |
# |     49     |     8     |
# |     50     |     10    |
# |     51     |     8     |
# |     52     |     8     |
# |     53     |     8     |
# |     54     |     5     |
# |     55     |     4     |
# |     56     |     1     |
# |     57     |     2     |
# |     58     |     4     |
# |     60     |     1     |
# +------------+-----------+

# %% [markdown]
# #### Performance by Country:
#
# ##### Which 5 country has the highest average test score?
# ##### Which 5 country has the lowest average test score?
# ##### How do the test scores vary across different countries?

# %%
# Which country has the highest average test score?
result = %sql select country, avg(test_score) as average_test_score from INTERNATIONAL_STUDENT_TEST_SCORES group by country ORDER BY Average_Test_Score DESC LIMIT 5

print("5 Country with the highest average test score:")
print(result)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# 5 Country with the highest average test score:
# +-----------+--------------------+
# |  country  | average_test_score |
# +-----------+--------------------+
# | Venezuela |        60.0        |
# |  Portugal |        56.0        |
# |   Uganda  |        55.0        |
# |   Sweden  |        54.0        |
# |   Niger   |        54.0        |
# +-----------+--------------------+

# %%
# Which 5 country has the lowest average test score?

result = %sql select country, avg(test_score) as average_test_score from INTERNATIONAL_STUDENT_TEST_SCORES group by country ORDER BY Average_Test_Score asc LIMIT 5

print("5 Country with the lowest average test score:")
print(result)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# 5 Country with the lowest average test score:
# +-----------+--------------------+
# |  country  | average_test_score |
# +-----------+--------------------+
# |  Moldova  |        38.0        |
# |  Jamaica  |        43.0        |
# | Argentina |        45.0        |
# |   Panama  |        45.0        |
# |   Russia  |        45.0        |
# +-----------+--------------------+

# %%
# How do the test scores vary across different countries?

result = %sql SELECT country, avg(test_score) AS Average_test_score FROM INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY country ORDER BY test_score desc
print("Test scores by country:")

print(result)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# Test scores by country:
# +------------------+--------------------+
# |     country      | Average_test_score |
# +------------------+--------------------+
# |    Venezuela     |        60.0        |
# |     Ireland      |        53.0        |
# |      China       | 50.69565217391305  |
# |     Portugal     |        56.0        |
# |      Uganda      |        55.0        |
# |      Sweden      |        54.0        |
# |    Indonesia     |       48.125       |
# |  United States   | 52.333333333333336 |
# |      Niger       |        54.0        |
# |     Vietnam      |        53.0        |
# |     Ukraine      |        53.0        |
# |      Norway      |        53.0        |
# |      Latvia      |        51.5        |
# |    Australia     |        53.0        |
# |  Czech Republic  |        50.0        |
# |      Ghana       |        51.0        |
# |     Armenia      |        51.0        |
# |   Philippines    |        51.2        |
# ...

# %% [markdown]
# ##### Top Performers:
#
# ###### Who are the top 5 students with the highest test scores?
# ###### What countries do these top-performing students come from?

# %%
result = %sql select first_name, last_name, test_score as top_5_Student_Highest_test_score FROM INTERNATIONAL_STUDENT_TEST_SCORES order by test_score desc limit 5;
print(result)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# +------------+-----------+----------------------------------+
# | first_name | last_name | top_5_Student_Highest_test_score |
# +------------+-----------+----------------------------------+
# |    Ron     |  Leggitt  |                60                |
# |   Tiffie   |   Cosely  |                58                |
# | Saunderson |    Root   |                58                |
# |   Wallis   |  Bartleet |                58                |
# |   Mendel   |  Grumble  |                58                |
# +------------+-----------+----------------------------------+

# %%
# What countries do these top-performing students come from? 

#result = %sql select first_name, last_name, test_score, country as Country_top_Performing_student FROM INTERNATIONAL_STUDENT_TEST_SCORES order by test_score desc limit 5;
#print(result)


result = %sql SELECT DISTINCT i.country FROM INTERNATIONAL_STUDENT_TEST_SCORES AS i WHERE (SELECT COUNT(*) FROM INTERNATIONAL_STUDENT_TEST_SCORES AS s WHERE s.test_score > i.test_score) < 6;
print(result)
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.
# +---------------+
# |    country    |
# +---------------+
# |     China     |
# | United States |
# |    Ireland    |
# |   Venezuela   |
# |  Philippines  |
# +---------------+

# %%
# What is the distribution of test scores within each country?
# Are there any outliers in the test scores?

import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a Pandas DataFrame
df = %sql SELECT * FROM INTERNATIONAL_STUDENT_TEST_SCORES
df = df.DataFrame()

# Plot boxplots to visualize the distribution of test scores within each country
plt.figure(figsize=(12, 6))
for country, group in grouped:
    unique_scores = group['test_score'].nunique()
    if unique_scores >= 3:
        plt.boxplot(group['test_score'], vert=False, labels=[country])
plt.title('Distribution of Test Scores within Each Country')
plt.xlabel('Test Score')
plt.ylabel('Country')
plt.show()
# Out:
#  * sqlite:///SQLiteMagic.db
# Done.

# %%
import seaborn as sns

# Create a boxplot using Seaborn
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='test_score', y='country')
plt.title('Distribution of Test Scores within Each Country')
plt.xlabel('Test Score')
plt.ylabel('Country')
plt.show()

# %%
#Set the style for Seaborn plots
sns.set(style="whitegrid")

#Plot 1: Histogram (Distribution of Test Scores)
plt.figure(figsize=(10, 5))
sns.distplot(df['test_score'], kde=True)
plt.title('Distribution of Test Scores')
plt.xlabel('Test Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot 3: Bar Chart (Average Scores by Country)
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='country', y='test_score', ci=None)
plt.title('Average Test Scores by Country')
plt.xlabel('Country')
plt.ylabel('Average Test Score')
plt.xticks(rotation=90)
plt.show()

# %%
# Plot 4: Scatter Plot (Test Score vs. Study Hours)
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='test_score', y='country')
plt.title('Test Score vs. Study Hours')
plt.xlabel('Test Score')
plt.ylabel('country')
plt.show()

# %%
# Identify outliers using the IQR method
outliers = {}
for country, group in grouped:
    Q1 = group['test_score'].quantile(0.25)
    Q3 = group['test_score'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers[country] = group[(group['test_score'] < lower_bound) | (group['test_score'] > upper_bound)]['test_score'].tolist()

# Print countries with outliers
print("Countries with outliers in test scores:")
for country, scores in outliers.items():
    if len(scores) > 0:
        print(f"{country}: {scores}")
# Out:
# Countries with outliers in test scores:
# Indonesia: [55]
# Philippines: [46, 57]

# %%
# Group data by first name and calculate the mean test score for each name
average_scores_by_first_name = df.groupby('first_name')['test_score'].mean().reset_index()

# Create a bar plot to visualize average test scores by first name
plt.figure(figsize=(12, 6))
sns.barplot(data=average_scores_by_first_name, x='first_name', y='test_score')
plt.title('Average Test Scores by First Name')
plt.xlabel('First Name')
plt.ylabel('Average Test Score')
plt.xticks(rotation=90)
plt.show()

# %%
# Group data by first name and calculate the mean test score for each name
average_scores_by_first_name = df.groupby('last_name')['test_score'].mean().reset_index()

# Create a bar plot to visualize average test scores by first name
plt.figure(figsize=(12, 6))
sns.barplot(data=average_scores_by_first_name, x='last_name', y='test_score')
plt.title('Average Test Scores by First Name')
plt.xlabel('Last Name')
plt.ylabel('Average Test Score')
plt.xticks(rotation=90)
plt.show()

# %%
# Test Score Ranges:

# How many students scored within specific test score ranges (e.g., 0-50, 51-75, 76-100)?
# What percentage of students fall into each range?

# Define score ranges and labels
score_ranges = [0, 50, 75, 100]
score_labels = ['0-50', '51-75', '76-100']

# Create a new column 'score_range' by binning the test scores
df['score_range'] = pd.cut(df['test_score'], bins=score_ranges, labels=score_labels, include_lowest=True)

# Count the number of students in each score range
score_range_counts = df['score_range'].value_counts().reset_index()
score_range_counts.columns = ['Score Range', 'Number of Students']

# Calculate the percentage of students in each range
total_students = len(df)
score_range_counts['Percentage'] = (score_range_counts['Number of Students'] / total_students) * 100

# Display the result
print(score_range_counts)

# %% [markdown]
#  Here are the questions you can explore and experiment with using the "INTERNATIONAL_STUDENT_TEST_SCORES" dataset:
#
# Time Spent Studying:
#
# Is there any correlation between the amount of time students spent studying and their test scores?

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Rav Ahuja</a>
#
# <a href="https://www.linkedin.com/in/lakshmi-holla-b39062149/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Lakshmi Holla</a>
#
#
#
# ## Other Contributor(s)
#
# <a href="https://www.linkedin.com/in/malika-goyal-04798622/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Malika</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                 |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 2022-03-04        | 1.0     | Lakshmi Holla     | Created lab using sqlite3          |
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2022. All rights reserved. <h3/>
